# %%
# Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from config import weather_api_key

# %%
# Create a set of random latitude and longite combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs =zip(lats,lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weathr data.
city_data =[]

# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | caravelas
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | marsabit
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | lopsmarka
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | sorland
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | la ferte-bernard
# Processing Record 17 of Set 1 | santa cruz do rio pardo
# Processing Record 18 of Set 1 | tricase
# Processing Record 19 of Set 1 | honningsvag
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | paamiut
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | rock sound
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | inirida
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | colborne
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | riachao do jacuipe
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | san lorenzo
# Processing Record 40 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 1 | mangrol
# Processing Record 42 of Set 1 | labrea
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | aurillac
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | vaasa
# Processing Record 50 of Set 1 | kavaratti
# Processing Record 1 of Set 2 | arlit
# Processing Record 2 of Set 2 | marathon
# Processing Record 3 of Set 2 | raichur
# Processing Record 4 of Set 2 | porto novo
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | beloha
# Processing Record 8 of Set 2 | santa maria da vitoria
# Processing Record 9 of Set 2 | kongoussi
# Processing Record 10 of Set 2 | alta floresta
# Processing Record 11 of Set 2 | stropkov
# Processing Record 12 of Set 2 | kaduna
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | tsumeb
# Processing Record 16 of Set 2 | saint anthony
# Processing Record 17 of Set 2 | limon
# Processing Record 18 of Set 2 | waldoboro
# Processing Record 19 of Set 2 | richards bay
# Processing Record 20 of Set 2 | oistins
# Processing Record 21 of Set 2 | ilulissat
# Processing Record 22 of Set 2 | boa vista
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 2 | beyneu
# Processing Record 26 of Set 2 | floro
# Processing Record 27 of Set 2 | harper
# Processing Record 28 of Set 2 | villamontes
# Processing Record 29 of Set 2 | timra
# Processing Record 30 of Set 2 | waddan
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | san carlos de bariloche
# Processing Record 33 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | yerkoy
# Processing Record 36 of Set 2 | urengoy
# Processing Record 37 of Set 2 | sisimiut
# Processing Record 38 of Set 2 | port blair
# Processing Record 39 of Set 2 | bachaquero
# Processing Record 40 of Set 2 | oranjemund
# Processing Record 41 of Set 2 | zhanaozen
# Processing Record 42 of Set 2 | trinidad
# Processing Record 43 of Set 2 | sao geraldo do araguaia
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | los algarrobos
# Processing Record 46 of Set 2 | burica
# City not found. Skipping...
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | kilmez
# City not found. Skipping...
# Processing Record 49 of Set 2 | ahwa
# Processing Record 50 of Set 2 | mount pleasant
# Processing Record 1 of Set 3 | avanigadda
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | cuamba
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | marsh harbour
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | obala
# Processing Record 8 of Set 3 | mansa
# Processing Record 9 of Set 3 | mehamn
# Processing Record 10 of Set 3 | ouesso
# Processing Record 11 of Set 3 | saint-augustin
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | aligudarz
# Processing Record 14 of Set 3 | sao jose da coroa grande
# Processing Record 15 of Set 3 | rawson
# Processing Record 16 of Set 3 | kochubey
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | uray
# Processing Record 19 of Set 3 | mahebourg
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | filadelfia
# Processing Record 22 of Set 3 | mantua
# Processing Record 23 of Set 3 | gornopravdinsk
# Processing Record 24 of Set 3 | florianopolis
# Processing Record 25 of Set 3 | perevolotskiy
# Processing Record 26 of Set 3 | morondava
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | nizwa
# Processing Record 30 of Set 3 | moroni
# Processing Record 31 of Set 3 | diamantino
# Processing Record 32 of Set 3 | madison
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | agirish
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | canoinhas
# Processing Record 37 of Set 3 | minsk
# Processing Record 38 of Set 3 | pavlovsk
# Processing Record 39 of Set 3 | beira
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | gazojak
# Processing Record 42 of Set 3 | ballina
# Processing Record 43 of Set 3 | viseu
# Processing Record 44 of Set 3 | gilgit
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | hearst
# Processing Record 47 of Set 3 | lunenburg
# Processing Record 48 of Set 3 | panama city
# Processing Record 49 of Set 3 | murgab
# Processing Record 50 of Set 3 | demir kapija
# Processing Record 1 of Set 4 | bani
# Processing Record 2 of Set 4 | leshukonskoye
# Processing Record 3 of Set 4 | chupa
# Processing Record 4 of Set 4 | dakar
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | goderich
# Processing Record 7 of Set 4 | jacqueville
# Processing Record 8 of Set 4 | camacari
# Processing Record 9 of Set 4 | trelew
# Processing Record 10 of Set 4 | sao filipe
# Processing Record 11 of Set 4 | puerto madryn
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | tiznit
# Processing Record 14 of Set 4 | san rafael
# Processing Record 15 of Set 4 | lekoni
# Processing Record 16 of Set 4 | vvedenskoye
# Processing Record 17 of Set 4 | henties bay
# Processing Record 18 of Set 4 | goure
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | khorixas
# Processing Record 21 of Set 4 | aksu
# Processing Record 22 of Set 4 | gat
# Processing Record 23 of Set 4 | chiredzi
# Processing Record 24 of Set 4 | canazas
# Processing Record 25 of Set 4 | tres arroyos
# Processing Record 26 of Set 4 | keti bandar
# Processing Record 27 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 4 | sande
# Processing Record 29 of Set 4 | akcakoca
# Processing Record 30 of Set 4 | sabha
# Processing Record 31 of Set 4 | pangnirtung
# Processing Record 32 of Set 4 | shelburne
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | halifax
# Processing Record 35 of Set 4 | manicore
# Processing Record 36 of Set 4 | tiruchchendur
# Processing Record 37 of Set 4 | port-cartier
# Processing Record 38 of Set 4 | idah
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | nylstroom
# City not found. Skipping...
# Processing Record 41 of Set 4 | oranjestad
# Processing Record 42 of Set 4 | kutum
# Processing Record 43 of Set 4 | husavik
# Processing Record 44 of Set 4 | tukrah
# Processing Record 45 of Set 4 | oriximina
# Processing Record 46 of Set 4 | guarapari
# Processing Record 47 of Set 4 | maneromango
# Processing Record 48 of Set 4 | turukhansk
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | tihemetsa
# Processing Record 1 of Set 5 | berlevag
# Processing Record 2 of Set 5 | mazagao
# Processing Record 3 of Set 5 | taoudenni
# Processing Record 4 of Set 5 | santarem
# Processing Record 5 of Set 5 | trairi
# Processing Record 6 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 5 | stavrovo
# Processing Record 8 of Set 5 | egersund
# Processing Record 9 of Set 5 | baghdad
# Processing Record 10 of Set 5 | storsteinnes
# Processing Record 11 of Set 5 | nortelandia
# Processing Record 12 of Set 5 | mar del plata
# Processing Record 13 of Set 5 | pobe
# Processing Record 14 of Set 5 | maceio
# Processing Record 15 of Set 5 | bedford
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | karad
# Processing Record 18 of Set 5 | doha
# Processing Record 19 of Set 5 | san juan
# Processing Record 20 of Set 5 | vakhtan
# Processing Record 21 of Set 5 | banfora
# Processing Record 22 of Set 5 | skegness
# Processing Record 23 of Set 5 | najran
# Processing Record 24 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 5 | suhut
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | edd
# Processing Record 28 of Set 5 | banda aceh
# Processing Record 29 of Set 5 | zenzeli
# Processing Record 30 of Set 5 | quatre cocos
# Processing Record 31 of Set 5 | brigantine
# Processing Record 32 of Set 5 | taltal
# Processing Record 33 of Set 5 | tenenkou
# Processing Record 34 of Set 5 | kozmodemyansk
# Processing Record 35 of Set 5 | ronne
# Processing Record 36 of Set 5 | ciudad bolivar
# Processing Record 37 of Set 5 | jumla
# Processing Record 38 of Set 5 | bud
# Processing Record 39 of Set 5 | khanpur
# Processing Record 40 of Set 5 | kosh-agach
# Processing Record 41 of Set 5 | sosnogorsk
# Processing Record 42 of Set 5 | baracoa
# Processing Record 43 of Set 5 | narasannapeta
# Processing Record 44 of Set 5 | bafia
# Processing Record 45 of Set 5 | newport
# Processing Record 46 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 5 | vorotynets
# Processing Record 48 of Set 5 | tarabuco
# Processing Record 49 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 5 | winchester
# Processing Record 1 of Set 6 | straumen
# Processing Record 2 of Set 6 | nouadhibou
# Processing Record 3 of Set 6 | umm kaddadah
# Processing Record 4 of Set 6 | mocuba
# Processing Record 5 of Set 6 | jalingo
# Processing Record 6 of Set 6 | catalao
# Processing Record 7 of Set 6 | aketi
# Processing Record 8 of Set 6 | brandenburg
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | cravo norte
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | onega
# Processing Record 13 of Set 6 | cabedelo
# Processing Record 14 of Set 6 | ouadda
# Processing Record 15 of Set 6 | savalou
# Processing Record 16 of Set 6 | sikonge
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | kyabe
# Processing Record 19 of Set 6 | uddevalla
# Processing Record 20 of Set 6 | savelugu
# Processing Record 21 of Set 6 | port-gentil
# Processing Record 22 of Set 6 | castro
# Processing Record 23 of Set 6 | grand gaube
# Processing Record 24 of Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 25 of Set 6 | puerto carreno
# Processing Record 26 of Set 6 | imatra
# Processing Record 27 of Set 6 | veinticinco de mayo
# Processing Record 28 of Set 6 | turayf
# Processing Record 29 of Set 6 | callosa de segura
# Processing Record 30 of Set 6 | necochea
# Processing Record 31 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 6 | puerto varas
# Processing Record 33 of Set 6 | camacha
# Processing Record 34 of Set 6 | susangerd
# Processing Record 35 of Set 6 | antalaha
# Processing Record 36 of Set 6 | aasiaat
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | yar-sale
# Processing Record 39 of Set 6 | puerto asis
# Processing Record 40 of Set 6 | khash
# Processing Record 41 of Set 6 | kinsale
# Processing Record 42 of Set 6 | assens
# Processing Record 43 of Set 6 | rudbar
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | presidente medici
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | bethanien
# Processing Record 48 of Set 6 | ginir
# Processing Record 49 of Set 6 | arrecife
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | suoyarvi
# Processing Record 2 of Set 7 | mian channun
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | mbandaka
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | plettenberg bay
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 7 | balapur
# Processing Record 10 of Set 7 | luau
# Processing Record 11 of Set 7 | willowmore
# Processing Record 12 of Set 7 | codrington
# Processing Record 13 of Set 7 | klaksvik
# Processing Record 14 of Set 7 | gazanjyk
# Processing Record 15 of Set 7 | belmonte
# Processing Record 16 of Set 7 | carutapera
# Processing Record 17 of Set 7 | bonavista
# Processing Record 18 of Set 7 | les cayes
# Processing Record 19 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 20 of Set 7 | sayyan
# Processing Record 21 of Set 7 | neuquen
# Processing Record 22 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 23 of Set 7 | bonthe
# Processing Record 24 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 7 | rondonopolis
# Processing Record 26 of Set 7 | bokoro
# Processing Record 27 of Set 7 | chegutu
# Processing Record 28 of Set 7 | puerto colombia
# Processing Record 29 of Set 7 | hatillo de loba
# Processing Record 30 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 31 of Set 7 | pietersburg
# Processing Record 32 of Set 7 | lukulu
# Processing Record 33 of Set 7 | nantucket
# Processing Record 34 of Set 7 | tromso
# Processing Record 35 of Set 7 | marzuq
# Processing Record 36 of Set 7 | astana
# Processing Record 37 of Set 7 | lodja
# Processing Record 38 of Set 7 | kyshtovka
# Processing Record 39 of Set 7 | swellendam
# Processing Record 40 of Set 7 | tarhunah
# City not found. Skipping...
# Processing Record 41 of Set 7 | damghan
# Processing Record 42 of Set 7 | ulagan
# Processing Record 43 of Set 7 | mooi river
# City not found. Skipping...
# Processing Record 44 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 45 of Set 7 | carbonia
# Processing Record 46 of Set 7 | charyshskoye
# Processing Record 47 of Set 7 | kulhudhuffushi
# Processing Record 48 of Set 7 | komsomolskiy
# Processing Record 49 of Set 7 | vaijapur
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | vila velha
# Processing Record 2 of Set 8 | ambikapur
# Processing Record 3 of Set 8 | hauterive
# Processing Record 4 of Set 8 | biala podlaska
# Processing Record 5 of Set 8 | chesma
# Processing Record 6 of Set 8 | catamarca
# Processing Record 7 of Set 8 | tobermory
# Processing Record 8 of Set 8 | mahibadhoo
# Processing Record 9 of Set 8 | manta
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | coari
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | guzelyurt
# Processing Record 14 of Set 8 | saint-francois
# Processing Record 15 of Set 8 | sao francisco de assis
# Processing Record 16 of Set 8 | tingo maria
# Processing Record 17 of Set 8 | cockburn town
# Processing Record 18 of Set 8 | san ignacio
# Processing Record 19 of Set 8 | gibara
# Processing Record 20 of Set 8 | leh
# Processing Record 21 of Set 8 | ekibastuz
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | zaysan
# Processing Record 24 of Set 8 | omutinskoye
# City not found. Skipping...
# Processing Record 25 of Set 8 | vila franca do campo
# Processing Record 26 of Set 8 | hobyo
# Processing Record 27 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 8 | nanuque
# Processing Record 29 of Set 8 | praia da vitoria
# Processing Record 30 of Set 8 | honavar
# Processing Record 31 of Set 8 | cermik
# Processing Record 32 of Set 8 | olinda
# Processing Record 33 of Set 8 | lagos
# Processing Record 34 of Set 8 | yaguaron
# Processing Record 35 of Set 8 | ust-koksa
# Processing Record 36 of Set 8 | talipparamba
# Processing Record 37 of Set 8 | salekhard
# Processing Record 38 of Set 8 | viedma
# Processing Record 39 of Set 8 | shush
# Processing Record 40 of Set 8 | ankazobe
# Processing Record 41 of Set 8 | lai
# Processing Record 42 of Set 8 | ashington
# Processing Record 43 of Set 8 | cookshire
# City not found. Skipping...
# Processing Record 44 of Set 8 | pilikwe
# Processing Record 45 of Set 8 | soyo
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | gari
# Processing Record 48 of Set 8 | siirt
# Processing Record 49 of Set 8 | meulaboh
# Processing Record 50 of Set 8 | shenkursk
# Processing Record 1 of Set 9 | mendi
# Processing Record 2 of Set 9 | am timan
# Processing Record 3 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 9 | impfondo
# Processing Record 5 of Set 9 | kibungo
# Processing Record 6 of Set 9 | huescar
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | mizdah
# Processing Record 9 of Set 9 | igra
# Processing Record 10 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | mundi
# Processing Record 12 of Set 9 | la paz
# Processing Record 13 of Set 9 | amapa
# Processing Record 14 of Set 9 | ebikon
# Processing Record 15 of Set 9 | okakarara
# Processing Record 16 of Set 9 | pangody
# Processing Record 17 of Set 9 | capao da canoa
# Processing Record 18 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 19 of Set 9 | kintinku
# Processing Record 20 of Set 9 | bilma
# Processing Record 21 of Set 9 | abu zabad
# Processing Record 22 of Set 9 | rockland
# Processing Record 23 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 24 of Set 9 | tessalit
# Processing Record 25 of Set 9 | aljezur
# Processing Record 26 of Set 9 | owando
# Processing Record 27 of Set 9 | kudahuvadhoo
# Processing Record 28 of Set 9 | abha
# Processing Record 29 of Set 9 | marienburg
# Processing Record 30 of Set 9 | natal
# Processing Record 31 of Set 9 | puerto ayacucho
# Processing Record 32 of Set 9 | soledade
# Processing Record 33 of Set 9 | lubango
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | bartica
# Processing Record 36 of Set 9 | vestmanna
# Processing Record 37 of Set 9 | bengkulu
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | pedasi
# Processing Record 40 of Set 9 | golovino
# Processing Record 41 of Set 9 | lock haven
# Processing Record 42 of Set 9 | lieksa
# Processing Record 43 of Set 9 | eruwa
# Processing Record 44 of Set 9 | hukuntsi
# Processing Record 45 of Set 9 | espanola
# Processing Record 46 of Set 9 | anloga
# Processing Record 47 of Set 9 | saint-medard-en-jalles
# Processing Record 48 of Set 9 | araouane
# Processing Record 49 of Set 9 | turochak
# Processing Record 50 of Set 9 | tibati
# Processing Record 1 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 2 of Set 10 | voitsberg
# Processing Record 3 of Set 10 | dalvik
# Processing Record 4 of Set 10 | margate
# Processing Record 5 of Set 10 | tonantins
# Processing Record 6 of Set 10 | norwalk
# Processing Record 7 of Set 10 | polyarnyy
# Processing Record 8 of Set 10 | salinas
# Processing Record 9 of Set 10 | issoire
# Processing Record 10 of Set 10 | djibo
# Processing Record 11 of Set 10 | asamankese
# Processing Record 12 of Set 10 | ode
# Processing Record 13 of Set 10 | san cristobal
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | yuksekova
# Processing Record 16 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 10 | maniitsoq
# Processing Record 18 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 19 of Set 10 | fondi
# Processing Record 20 of Set 10 | salinopolis
# Processing Record 21 of Set 10 | hochst
# Processing Record 22 of Set 10 | wilmington
# Processing Record 23 of Set 10 | gilgil
# City not found. Skipping...
# Processing Record 24 of Set 10 | kralendijk
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | jamsa
# Processing Record 27 of Set 10 | benghazi
# Processing Record 28 of Set 10 | gouyave
# Processing Record 29 of Set 10 | urumqi
# Processing Record 30 of Set 10 | toccoa
# Processing Record 31 of Set 10 | neustrelitz
# Processing Record 32 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 10 | the valley
# Processing Record 34 of Set 10 | annonay
# Processing Record 35 of Set 10 | mokrousovo
# Processing Record 36 of Set 10 | carahue
# Processing Record 37 of Set 10 | jesup
# Processing Record 38 of Set 10 | chimbote
# Processing Record 39 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 10 | awjilah
# Processing Record 41 of Set 10 | ilhabela
# Processing Record 42 of Set 10 | bardiyah
# Processing Record 43 of Set 10 | karasjok
# Processing Record 44 of Set 10 | talcahuano
# Processing Record 45 of Set 10 | volta redonda
# Processing Record 46 of Set 10 | chapais
# Processing Record 47 of Set 10 | high rock
# Processing Record 48 of Set 10 | ortakoy
# Processing Record 49 of Set 10 | miranda
# Processing Record 50 of Set 10 | samana
# Processing Record 1 of Set 11 | roznava
# Processing Record 2 of Set 11 | mercedes
# Processing Record 3 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 11 | naivasha
# Processing Record 5 of Set 11 | beirut
# Processing Record 6 of Set 11 | itarema
# Processing Record 7 of Set 11 | iguape
# Processing Record 8 of Set 11 | kapoeta
# Processing Record 9 of Set 11 | guipavas
# Processing Record 10 of Set 11 | verkh-suetka
# Processing Record 11 of Set 11 | ratnagiri
# Processing Record 12 of Set 11 | formosa do rio preto
# Processing Record 13 of Set 11 | verkhnyachka
# Processing Record 14 of Set 11 | aswan
# Processing Record 15 of Set 11 | banepa
# Processing Record 16 of Set 11 | hofn
# Processing Record 17 of Set 11 | abu samrah
# Processing Record 18 of Set 11 | xuddur
# Processing Record 19 of Set 11 | dwarka
# Processing Record 20 of Set 11 | frauenfeld
# Processing Record 21 of Set 11 | le port
# Processing Record 22 of Set 11 | korla
# Processing Record 23 of Set 11 | kinkala
# Processing Record 24 of Set 11 | novopskov
# Processing Record 25 of Set 11 | trofors
# Processing Record 26 of Set 11 | boden
# Processing Record 27 of Set 11 | nizhnekamsk
# Processing Record 28 of Set 11 | port shepstone
# Processing Record 29 of Set 11 | uyemskiy
# Processing Record 30 of Set 11 | albany
# Processing Record 31 of Set 11 | rognan
# Processing Record 32 of Set 11 | sokoni
# Processing Record 33 of Set 11 | gewane
# Processing Record 34 of Set 11 | laukaa
# Processing Record 35 of Set 11 | zhurivka
# Processing Record 36 of Set 11 | pauini
# Processing Record 37 of Set 11 | itaituba
# Processing Record 38 of Set 11 | kargat
# Processing Record 39 of Set 11 | sidi ali
# Processing Record 40 of Set 11 | santa fe
# Processing Record 41 of Set 11 | hambantota
# Processing Record 42 of Set 11 | yarmouth
# Processing Record 43 of Set 11 | lukovetskiy
# Processing Record 44 of Set 11 | kemijarvi
# Processing Record 45 of Set 11 | gainesville
# Processing Record 46 of Set 11 | luena
# Processing Record 47 of Set 11 | uppsala
# Processing Record 48 of Set 11 | coripata
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 50 of Set 11 | boke
# Processing Record 1 of Set 12 | pointe michel
# Processing Record 2 of Set 12 | eucaliptus
# Processing Record 3 of Set 12 | balkhash
# Processing Record 4 of Set 12 | hurghada
# Processing Record 5 of Set 12 | monrovia
# Processing Record 6 of Set 12 | octeville
# Processing Record 7 of Set 12 | roald
# Processing Record 8 of Set 12 | maldonado
# Processing Record 9 of Set 12 | beckley
# Processing Record 10 of Set 12 | siva
# Processing Record 11 of Set 12 | sura
# Processing Record 12 of Set 12 | arandis
# Processing Record 13 of Set 12 | diffa
# Processing Record 14 of Set 12 | taywarah
# Processing Record 15 of Set 12 | qaqortoq
# Processing Record 16 of Set 12 | kasempa
# Processing Record 17 of Set 12 | venado tuerto
# Processing Record 18 of Set 12 | saint-joseph
# Processing Record 19 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 12 | barentu
# Processing Record 21 of Set 12 | polunochnoye
# Processing Record 22 of Set 12 | rio grande
# Processing Record 23 of Set 12 | marawi
# Processing Record 24 of Set 12 | pangoa
# Processing Record 25 of Set 12 | san andres
# Processing Record 26 of Set 12 | ajaccio
# Processing Record 27 of Set 12 | umm lajj
# Processing Record 28 of Set 12 | wana
# Processing Record 29 of Set 12 | kalmunai
# Processing Record 30 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 12 | cap-haitien
# Processing Record 32 of Set 12 | veraval
# Processing Record 33 of Set 12 | conde
# Processing Record 34 of Set 12 | nacala
# Processing Record 35 of Set 12 | muros
# Processing Record 36 of Set 12 | urmary
# Processing Record 37 of Set 12 | canandaigua
# Processing Record 38 of Set 12 | muravlenko
# Processing Record 39 of Set 12 | donegal
# Processing Record 40 of Set 12 | bushehr
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | ornes
# Processing Record 43 of Set 12 | osmaniye
# Processing Record 44 of Set 12 | domoni
# Processing Record 45 of Set 12 | zhizdra
# Processing Record 46 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 12 | semey
# Processing Record 48 of Set 12 | tahta
# Processing Record 49 of Set 12 | nuuk
# Processing Record 50 of Set 12 | sao domingos
# Processing Record 1 of Set 13 | santa cruz
# Processing Record 2 of Set 13 | yining
# Processing Record 3 of Set 13 | bikaner
# Processing Record 4 of Set 13 | ziarat
# Processing Record 5 of Set 13 | itacoatiara
# Processing Record 6 of Set 13 | strezhevoy
# Processing Record 7 of Set 13 | kalol
# Processing Record 8 of Set 13 | parana
# Processing Record 9 of Set 13 | lodwar
# Processing Record 10 of Set 13 | kemin
# Processing Record 11 of Set 13 | mucurapo
# Processing Record 12 of Set 13 | kristiinankaupunki
# Processing Record 13 of Set 13 | qandala
# Processing Record 14 of Set 13 | kastamonu
# Processing Record 15 of Set 13 | porto nacional
# Processing Record 16 of Set 13 | altay
# Processing Record 17 of Set 13 | boralday
# Processing Record 18 of Set 13 | iralaya
# Processing Record 19 of Set 13 | pervomayskoye
# Processing Record 20 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 21 of Set 13 | ibra
# Processing Record 22 of Set 13 | aranos
# Processing Record 23 of Set 13 | bani walid
# Processing Record 24 of Set 13 | toamasina
# Processing Record 25 of Set 13 | mitsamiouli
# Processing Record 26 of Set 13 | anuradhapura
# Processing Record 27 of Set 13 | inhambane
# Processing Record 28 of Set 13 | biltine
# Processing Record 29 of Set 13 | selma
# Processing Record 30 of Set 13 | wesselsbron
# Processing Record 31 of Set 13 | yarqa
# Processing Record 32 of Set 13 | luanda
# Processing Record 33 of Set 13 | manono
# Processing Record 34 of Set 13 | ondjiva
# Processing Record 35 of Set 13 | tamandare
# Processing Record 36 of Set 13 | galle
# Processing Record 37 of Set 13 | nizhnevartovsk
# Processing Record 38 of Set 13 | totness
# Processing Record 39 of Set 13 | birao
# Processing Record 40 of Set 13 | mao
# Processing Record 41 of Set 13 | beisfjord
# Processing Record 42 of Set 13 | topolovgrad
# Processing Record 43 of Set 13 | bembereke
# Processing Record 44 of Set 13 | kindu
# Processing Record 45 of Set 13 | muscat
# Processing Record 46 of Set 13 | mendoza
# Processing Record 47 of Set 13 | mtambile
# Processing Record 48 of Set 13 | hit
# Processing Record 49 of Set 13 | serowe
# Processing Record 50 of Set 13 | yendi
# Processing Record 1 of Set 14 | vlore
# Processing Record 2 of Set 14 | micheweni
# Processing Record 3 of Set 14 | kontagora
# Processing Record 4 of Set 14 | aguimes
# Processing Record 5 of Set 14 | howell
# Processing Record 6 of Set 14 | springbok
# Processing Record 7 of Set 14 | havelock
# Processing Record 8 of Set 14 | iskateley
# Processing Record 9 of Set 14 | gao
# Processing Record 10 of Set 14 | aflao
# Processing Record 11 of Set 14 | bafq
# Processing Record 12 of Set 14 | agadir
# Processing Record 13 of Set 14 | maxixe
# Processing Record 14 of Set 14 | sechura
# Processing Record 15 of Set 14 | van
# Processing Record 16 of Set 14 | mirador
# Processing Record 17 of Set 14 | mathbaria
# Processing Record 18 of Set 14 | chicama
# Processing Record 19 of Set 14 | eskisehir
# Processing Record 20 of Set 14 | gdansk
# Processing Record 21 of Set 14 | bloomingdale
# Processing Record 22 of Set 14 | umtata
# Processing Record 23 of Set 14 | olot
# Processing Record 24 of Set 14 | baena
# Processing Record 25 of Set 14 | mecca
# Processing Record 26 of Set 14 | vieux-habitants
# Processing Record 27 of Set 14 | tashtyp
# Processing Record 28 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 29 of Set 14 | sinnamary
# Processing Record 30 of Set 14 | mogapinyana
# Processing Record 31 of Set 14 | virbhadra
# Processing Record 32 of Set 14 | balsas
# Processing Record 33 of Set 14 | siderno
# Processing Record 34 of Set 14 | kankan
# Processing Record 35 of Set 14 | valday
# Processing Record 36 of Set 14 | kattivakkam
# Processing Record 37 of Set 14 | puerto baquerizo moreno
# Processing Record 38 of Set 14 | comodoro rivadavia
# Processing Record 39 of Set 14 | ouidah
# Processing Record 40 of Set 14 | beinamar
# Processing Record 41 of Set 14 | morada nova
# Processing Record 42 of Set 14 | muisne
# Processing Record 43 of Set 14 | ogulin
# Processing Record 44 of Set 14 | diego de almagro
# Processing Record 45 of Set 14 | banyo
# Processing Record 46 of Set 14 | kolo
# Processing Record 47 of Set 14 | fonte boa
# Processing Record 48 of Set 14 | dinga
# Processing Record 49 of Set 14 | wattegama
# Processing Record 50 of Set 14 | damietta
# Processing Record 1 of Set 15 | aquiraz
# Processing Record 2 of Set 15 | libertador general san martin
# Processing Record 3 of Set 15 | adwa
# Processing Record 4 of Set 15 | sur
# Processing Record 5 of Set 15 | boende
# Processing Record 6 of Set 15 | ankazoabo
# Processing Record 7 of Set 15 | carnarvon
# Processing Record 8 of Set 15 | lapua
# Processing Record 9 of Set 15 | iglesias
# Processing Record 10 of Set 15 | assen
# Processing Record 11 of Set 15 | staryy krym
# Processing Record 12 of Set 15 | rio gallegos
# Processing Record 13 of Set 15 | larsnes
# Processing Record 14 of Set 15 | togur
# Processing Record 15 of Set 15 | cupira
# Processing Record 16 of Set 15 | sabla
# Processing Record 17 of Set 15 | iisalmi
# Processing Record 18 of Set 15 | rjukan
# Processing Record 19 of Set 15 | setermoen
# Processing Record 20 of Set 15 | teguise
# Processing Record 21 of Set 15 | nyimba
# Processing Record 22 of Set 15 | harrison
# Processing Record 23 of Set 15 | kargasok
# Processing Record 24 of Set 15 | bjornevatn
# Processing Record 25 of Set 15 | keflavik
# Processing Record 26 of Set 15 | scaesti
# Processing Record 27 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 15 | imbituba
# Processing Record 29 of Set 15 | cascais
# Processing Record 30 of Set 15 | rio bananal
# Processing Record 31 of Set 15 | nicoya
# Processing Record 32 of Set 15 | soron
# Processing Record 33 of Set 15 | america dourada
# Processing Record 34 of Set 15 | urucui
# Processing Record 35 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 15 | lugovoy
# Processing Record 37 of Set 15 | pierrelatte
# Processing Record 38 of Set 15 | lucapa
# Processing Record 39 of Set 15 | schwarzenbek
# Processing Record 40 of Set 15 | cantanhede
# Processing Record 41 of Set 15 | idritsa
# Processing Record 42 of Set 15 | mungeli
# Processing Record 43 of Set 15 | geraldton
# Processing Record 44 of Set 15 | artyom
# Processing Record 45 of Set 15 | nouakchott
# Processing Record 46 of Set 15 | bodden town
# Processing Record 47 of Set 15 | breves
# Processing Record 48 of Set 15 | elvas
# Processing Record 49 of Set 15 | mikkeli
# Processing Record 50 of Set 15 | atbasar
# Processing Record 1 of Set 16 | westport
# Processing Record 2 of Set 16 | teruel
# Processing Record 3 of Set 16 | terra santa
# Processing Record 4 of Set 16 | mishawaka
# Processing Record 5 of Set 16 | faya
# Processing Record 6 of Set 16 | mortka
# Processing Record 7 of Set 16 | sistranda
# Processing Record 8 of Set 16 | pascagoula
# Processing Record 9 of Set 16 | pishchanka
# City not found. Skipping...
# Processing Record 10 of Set 16 | ambilobe
# Processing Record 11 of Set 16 | saint-raymond
# Processing Record 12 of Set 16 | jacareacanga
# Processing Record 13 of Set 16 | sept-iles
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# %%
# Create the output file (CSV).
output_data_file = "Weather_DataBase/WeatherPy_DataBase.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
